# %%
import pandas as pd
import plotly.express as px
import geopandas as gpd
import folium

import numpy as np

# %%
# Load data for the number of wind turbines and total energy produced
data = pd.read_csv('cleaned_data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      760 non-null    int64
#  1   ref_id                          760 non-null    int64
#  2   last_updated                    758 non-null    object
#  3   operator_or_applicant           743 non-null    object
#  4   site_name                       760 non-null    object
#  5   capacity_mw                     760 non-null    float64
#  6   turbine_capacity_mw             759 non-null    float64
#  7   no_of_turbines                  760 non-null    float64
#  8   height_of_turbines_m            73 non-null     float64
#  9   development_status              760 non-null    object
#  10  development_status_short        760 non-null    object
#  11  address                         759 non-null    object
#  12  county                          760 non-null    object
#  13  region                          760 non-null    object
#  14  country                         760 non-null    object
#  15  post_code                       134 non-null    object
#  16  xcoord                          760 non-null    float64
#  17  ycoord                          760 non-null    float64
#  18  planning_authority              760 non-null    object
#  19  planning_application_reference  643 non-null    object
#  20  appeal_reference                107 non-null    object
#  21  planning_application_submitted  747 non-null    object
#  22  planning_application_withdrawn  0 non-null      float64
#  23  planning_permission_refused     178 non-null    object
#  24  appeal_lodged                   25 non-null     object
#  25  appeal_withdrawn                0 non-null      float64
#  26  appeal_refused                  0 non-null      float64
#  27  appeal_granted                  138 non-null    object
#  28  planning_permission_granted     715 non-null    object
#  29  planning_permission_expired     77 non-null     object
#  30  under_construction              530 non-null    object
#  31  operational                     759 non-null    object
#  32  decom_year                      7 non-null      float64
#  33  start_year                      759 non-null    float64
# dtypes: float64(11), int64(2), object(21)
# memory usage: 202.0+ KB

# %%
# Convert the date column to a proper datetime format
data['last_updated'] = pd.to_datetime(data['last_updated'])

# %%
data['decom_year'] = data['decom_year'].astype('Int64')
data['start_year'] = data['start_year'].astype('Int64')

# %%
data
# Out:
#      Unnamed: 0  ref_id last_updated      operator_or_applicant  \
# 0           240    2948   2015-01-09              Wind Electric
# 1           216    2921   2009-07-06            Yorkshire Water
# 2           284    3005   2015-01-09  Scottish Power Renewables
# 3           823    3659   2013-10-08      Border Wind Farms Ltd
# 4           107    2713   2019-08-05          Npower Renewables
# ..          ...     ...          ...                        ...
# 755        2105    7562   2020-09-23               Statkraft UK
# 756        1981    6422   2023-03-16                Cleanearth
# 757        2054    7304          NaT       Green Cat Renewables
# 758        1424    4300   2023-01-16                        ERG
# 759        2102    7544   2022-03-30          Private Developer
#
#                           site_name  capacity_mw  turbine_capacity_mw  \
# 0                Delabole Wind Farm          4.0                 0.40
# 1                 Chelker Reservoir          1.3                 0.30
# 2                     Carland Cross          6.0                 0.40
# 3           Blyth Harbour Wind Farm          2.7                 0.30
# 4                       Kirkby Moor          4.8                 0.40
# ..                              ...          ...                  ...
# 755            Windy Rig Wind Farm          43.0                 3.00
# 756                Graig Fatha Farm          2.5                 2.50
# 757  Deuchries Windfarm (extension)          2.0                 1.00
# 758        Creag Riabhach Wind Farm         90.0                 4.20
# 759                  Dundrinne Road          0.2                 0.23
#
#      no_of_turbines  height_of_turbines_m development_status  ...  \
# 0              10.0                   NaN     Decommissioned  ...
# 1               4.0                   NaN        Operational  ...
# 2              15.0                   NaN     Decommissioned  ...
# 3               9.0                   NaN        Operational  ...
# 4              12.0                   NaN        Operational  ...
# ..              ...                   ...                ...  ...
# 755            12.0                 125.0        Operational  ...
# 756             1.0                 126.0        Operational  ...
# 757             2.0                 119.0        Operational  ...
# 758            22.0                 125.0        Operational  ...
# 759             1.0                  40.0        Operational  ...
#
#     appeal_lodged appeal_withdrawn appeal_refused appeal_granted  \
# 0             NaN              NaN            NaN            NaN
# 1             NaN              NaN            NaN            NaN
# 2             NaN              NaN            NaN            NaN
# 3             NaN              NaN            NaN            NaN
# 4             NaN              NaN            NaN            NaN
# ..            ...              ...            ...            ...
# 755           NaN              NaN            NaN            NaN
# 756           NaN              NaN            NaN            NaN
# 757           NaN              NaN            NaN            NaN
# 758           NaN              NaN            NaN            NaN
# 759           NaN              NaN            NaN            NaN
#
#     planning_permission_granted planning_permission_expired  \
# 0                           NaN                         NaN
# 1                    1991-07-12                         NaN
# 2                    1992-04-29                         NaN
# 3                    1992-03-06                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 755                  2019-11-08                  2022-11-07
# 756                  2018-03-14                  2023-03-14
# 757                  2019-10-08                  2022-10-08
# 758                  2016-10-17                         NaN
# 759                  2022-03-09                         NaN
#
#      under_construction  operational decom_year start_year
# 0                   NaN   1991-11-01       2015       1991
# 1                   NaN   1992-06-01       <NA>       1992
# 2                   NaN   1992-08-27       2015       1992
# 3                   NaN   1992-12-01       <NA>       1992
# 4                   NaN   1993-01-01       <NA>       1993
# ..                  ...          ...        ...        ...
# 755          2020-03-01   2022-01-10       <NA>       2022
# 756          2021-10-01   2022-02-01       <NA>       2022
# 757                 NaN   2022-04-01       <NA>       2022
# 758          2021-05-24   2023-01-12       <NA>       2023
# 759                 NaN          NaN       <NA>       <NA>
#
# [760 rows x 34 columns]

# %%
def date_converter(dataframe, column_list, fmt):
    for column in column_list:
        dataframe[column] = pd.to_datetime(dataframe[column], format=fmt)
    return data

# %%
data = date_converter(data, ['decom_year','start_year'], fmt='%Y')
data = date_converter(data, ['last_updated','operational','planning_permission_granted'], fmt='%Y-%m-%d')

# %%
data
# Out:
#      Unnamed: 0  ref_id last_updated      operator_or_applicant  \
# 0           240    2948   2015-01-09              Wind Electric
# 1           216    2921   2009-07-06            Yorkshire Water
# 2           284    3005   2015-01-09  Scottish Power Renewables
# 3           823    3659   2013-10-08      Border Wind Farms Ltd
# 4           107    2713   2019-08-05          Npower Renewables
# ..          ...     ...          ...                        ...
# 755        2105    7562   2020-09-23               Statkraft UK
# 756        1981    6422   2023-03-16                Cleanearth
# 757        2054    7304          NaT       Green Cat Renewables
# 758        1424    4300   2023-01-16                        ERG
# 759        2102    7544   2022-03-30          Private Developer
#
#                           site_name  capacity_mw  turbine_capacity_mw  \
# 0                Delabole Wind Farm          4.0                 0.40
# 1                 Chelker Reservoir          1.3                 0.30
# 2                     Carland Cross          6.0                 0.40
# 3           Blyth Harbour Wind Farm          2.7                 0.30
# 4                       Kirkby Moor          4.8                 0.40
# ..                              ...          ...                  ...
# 755            Windy Rig Wind Farm          43.0                 3.00
# 756                Graig Fatha Farm          2.5                 2.50
# 757  Deuchries Windfarm (extension)          2.0                 1.00
# 758        Creag Riabhach Wind Farm         90.0                 4.20
# 759                  Dundrinne Road          0.2                 0.23
#
#      no_of_turbines  height_of_turbines_m development_status  ...  \
# 0              10.0                   NaN     Decommissioned  ...
# 1               4.0                   NaN        Operational  ...
# 2              15.0                   NaN     Decommissioned  ...
# 3               9.0                   NaN        Operational  ...
# 4              12.0                   NaN        Operational  ...
# ..              ...                   ...                ...  ...
# 755            12.0                 125.0        Operational  ...
# 756             1.0                 126.0        Operational  ...
# 757             2.0                 119.0        Operational  ...
# 758            22.0                 125.0        Operational  ...
# 759             1.0                  40.0        Operational  ...
#
#     appeal_lodged appeal_withdrawn appeal_refused appeal_granted  \
# 0             NaN              NaN            NaN            NaN
# 1             NaN              NaN            NaN            NaN
# 2             NaN              NaN            NaN            NaN
# 3             NaN              NaN            NaN            NaN
# 4             NaN              NaN            NaN            NaN
# ..            ...              ...            ...            ...
# 755           NaN              NaN            NaN            NaN
# 756           NaN              NaN            NaN            NaN
# 757           NaN              NaN            NaN            NaN
# 758           NaN              NaN            NaN            NaN
# 759           NaN              NaN            NaN            NaN
#
#     planning_permission_granted planning_permission_expired  \
# 0                           NaT                         NaN
# 1                    1991-07-12                         NaN
# 2                    1992-04-29                         NaN
# 3                    1992-03-06                         NaN
# 4                           NaT                         NaN
# ..                          ...                         ...
# 755                  2019-11-08                  2022-11-07
# 756                  2018-03-14                  2023-03-14
# 757                  2019-10-08                  2022-10-08
# 758                  2016-10-17                         NaN
# 759                  2022-03-09                         NaN
#
#      under_construction  operational decom_year start_year
# 0                   NaN   1991-11-01 2015-01-01 1991-01-01
# 1                   NaN   1992-06-01        NaT 1992-01-01
# 2                   NaN   1992-08-27 2015-01-01 1992-01-01
# 3                   NaN   1992-12-01        NaT 1992-01-01
# 4                   NaN   1993-01-01        NaT 1993-01-01
# ..                  ...          ...        ...        ...
# 755          2020-03-01   2022-01-10        NaT 2022-01-01
# 756          2021-10-01   2022-02-01        NaT 2022-01-01
# 757                 NaN   2022-04-01        NaT 2022-01-01
# 758          2021-05-24   2023-01-12        NaT 2023-01-01
# 759                 NaN          NaT        NaT        NaT
#
# [760 rows x 34 columns]

# %%
#Sum the number of turbines annually
years_turbines = data.groupby('start_year')['no_of_turbines'].sum()
years_turbines = pd.DataFrame(years_turbines).reset_index()
years_turbines
# Out:
#    start_year  no_of_turbines
# 0  1991-01-01            10.0
# 1  1992-01-01            28.0
# 2  1993-01-01           209.0
# 3  1994-01-01            53.0
# 4  1995-01-01            56.0
# 5  1996-01-01           122.0
# 6  1997-01-01            88.0
# 7  1998-01-01            38.0
# 8  1999-01-01            34.0
# 9  2000-01-01            90.0
# 10 2001-01-01           117.0
# 11 2002-01-01           139.0
# 12 2003-01-01            45.0
# 13 2004-01-01           211.0
# 14 2005-01-01           302.0
# 15 2006-01-01           200.0
# 16 2007-01-01           284.0
# 17 2008-01-01           314.0
# 18 2009-01-01           217.0
# 19 2010-01-01           293.0
# 20 2011-01-01           245.0
# 21 2012-01-01           596.0
# 22 2013-01-01           671.0
# 23 2014-01-01           391.0
# 24 2015-01-01           278.0
# 25 2016-01-01           586.0
# 26 2017-01-01           806.0
# 27 2018-01-01           328.0
# 28 2019-01-01           142.0
# 29 2020-01-01            37.0
# 30 2021-01-01            57.0
# 31 2022-01-01            35.0
# 32 2023-01-01            22.0

# %%
#Sum the number of projects decommissioned each year
decom_projects = data[data['decom_year'] != np.NaN]
decom_projects = decom_projects.groupby('decom_year')['no_of_turbines'].sum()
decom_projects
# Out:
# decom_year
# 2015-01-01    76.0
# 2019-01-01     2.0
# Name: no_of_turbines, dtype: float64

# %%
#Bring the two together to find out the number of projects active each year
total_turbs = pd.merge(years_turbines, decom_projects, how='left', left_on='start_year', right_on='decom_year')
total_turbs.rename(columns={'no_of_turbines_x':'operational','no_of_turbines_y':'decommissioned'}, inplace=True)
total_turbs
# Out:
#    start_year  operational  decommissioned
# 0  1991-01-01         10.0             NaN
# 1  1992-01-01         28.0             NaN
# 2  1993-01-01        209.0             NaN
# 3  1994-01-01         53.0             NaN
# 4  1995-01-01         56.0             NaN
# 5  1996-01-01        122.0             NaN
# 6  1997-01-01         88.0             NaN
# 7  1998-01-01         38.0             NaN
# 8  1999-01-01         34.0             NaN
# 9  2000-01-01         90.0             NaN
# 10 2001-01-01        117.0             NaN
# 11 2002-01-01        139.0             NaN
# 12 2003-01-01         45.0             NaN
# 13 2004-01-01        211.0             NaN
# 14 2005-01-01        302.0             NaN
# 15 2006-01-01        200.0             NaN
# 16 2007-01-01        284.0             NaN
# 17 2008-01-01        314.0             NaN
# 18 2009-01-01        217.0             NaN
# 19 2010-01-01        293.0             NaN
# 20 2011-01-01        245.0             NaN
# 21 2012-01-01        596.0             NaN
# 22 2013-01-01        671.0             NaN
# 23 2014-01-01        391.0             NaN
# 24 2015-01-01        278.0            76.0
# 25 2016-01-01        586.0             NaN
# 26 2017-01-01        806.0             NaN
# 27 2018-01-01        328.0             NaN
# 28 2019-01-01        142.0             2.0
# 29 2020-01-01         37.0             NaN
# 30 2021-01-01         57.0             NaN
# 31 2022-01-01         35.0             NaN
# 32 2023-01-01         22.0             NaN

# %%
total_turbs['decommissioned'] = total_turbs['decommissioned'].fillna(0)
total_turbs['total'] = total_turbs['operational'] - total_turbs['decommissioned']
total_turbs['cumul_total'] = total_turbs['total'].cumsum()
total_turbs
# Out:
#    start_year  operational  decommissioned  total  cumul_total
# 0  1991-01-01         10.0             0.0   10.0         10.0
# 1  1992-01-01         28.0             0.0   28.0         38.0
# 2  1993-01-01        209.0             0.0  209.0        247.0
# 3  1994-01-01         53.0             0.0   53.0        300.0
# 4  1995-01-01         56.0             0.0   56.0        356.0
# 5  1996-01-01        122.0             0.0  122.0        478.0
# 6  1997-01-01         88.0             0.0   88.0        566.0
# 7  1998-01-01         38.0             0.0   38.0        604.0
# 8  1999-01-01         34.0             0.0   34.0        638.0
# 9  2000-01-01         90.0             0.0   90.0        728.0
# 10 2001-01-01        117.0             0.0  117.0        845.0
# 11 2002-01-01        139.0             0.0  139.0        984.0
# 12 2003-01-01         45.0             0.0   45.0       1029.0
# 13 2004-01-01        211.0             0.0  211.0       1240.0
# 14 2005-01-01        302.0             0.0  302.0       1542.0
# 15 2006-01-01        200.0             0.0  200.0       1742.0
# 16 2007-01-01        284.0             0.0  284.0       2026.0
# 17 2008-01-01        314.0             0.0  314.0       2340.0
# 18 2009-01-01        217.0             0.0  217.0       2557.0
# 19 2010-01-01        293.0             0.0  293.0       2850.0
# 20 2011-01-01        245.0             0.0  245.0       3095.0
# 21 2012-01-01        596.0             0.0  596.0       3691.0
# 22 2013-01-01        671.0             0.0  671.0       4362.0
# 23 2014-01-01        391.0             0.0  391.0       4753.0
# 24 2015-01-01        278.0            76.0  202.0       4955.0
# 25 2016-01-01        586.0             0.0  586.0       5541.0
# 26 2017-01-01        806.0             0.0  806.0       6347.0
# 27 2018-01-01        328.0             0.0  328.0       6675.0
# 28 2019-01-01        142.0             2.0  140.0       6815.0
# 29 2020-01-01         37.0             0.0   37.0       6852.0
# 30 2021-01-01         57.0             0.0   57.0       6909.0
# 31 2022-01-01         35.0             0.0   35.0       6944.0
# 32 2023-01-01         22.0             0.0   22.0       6966.0

# %%
#Did a similar thing to the above already elsewhere to calculate the energy produced annually
years_mw = pd.read_csv('years_mw.csv')
years_mw
# Out:
#     Unnamed: 0  start_year  ops_capacity  decom_capacity   total  \
# 0            0        1991           4.0             0.0     4.0
# 1            1        1992          10.0             0.0    10.0
# 2            2        1993          75.1             0.0    75.1
# 3            3        1994          25.4             0.0    25.4
# 4            4        1995          30.6             0.0    30.6
# 5            5        1996          70.4             0.0    70.4
# 6            6        1997          59.3             0.0    59.3
# 7            7        1998          17.1             0.0    17.1
# 8            8        1999          20.9             0.0    20.9
# 9            9        2000          56.4             0.0    56.4
# 10          10        2001          92.2             0.0    92.2
# 11          11        2002         127.5             0.0   127.5
# 12          12        2003          68.6             0.0    68.6
# 13          13        2004         374.9             0.0   374.9
# 14          14        2005         421.8             0.0   421.8
# 15          15        2006         418.1             0.0   418.1
# 16          16        2007         572.0             0.0   572.0
# 17          17        2008         619.9             0.0   619.9
# 18          18        2009         394.3             0.0   394.3
# 19          19        2010         597.7             0.0   597.7
# 20          20        2011         504.1             0.0   504.1
# 21          21        2012        1328.2             0.0  1328.2
# 22          22        2013        1528.6             0.0  1528.6
# 23          23        2014         839.9             0.0   839.9
# 24          24        2015         591.2            38.1   553.1
# 25          25        2016        1321.1             0.0  1321.1
# 26          26        2017        2082.7             0.0  2082.7
# 27          27        2018         877.0             0.0   877.0
# 28          28        2019         372.5            13.0   359.5
# 29          29        2020          82.2             0.0    82.2
# 30          30        2021         185.1             0.0   185.1
# 31          31        2022          96.0             0.0    96.0
# 32          32        2023          90.0             0.0    90.0
#
#     cumulative_capacity  load_factor   GWh_annual  TWh_annual
# 0                   4.0         0.27      9.46080    0.009461
# 1                  14.0         0.27     33.11280    0.033113
# 2                  89.1         0.27    210.73932    0.210739
# 3                 114.5         0.27    270.81540    0.270815
# 4                 145.1         0.27    343.19052    0.343191
# 5                 215.5         0.27    509.70060    0.509701
# 6                 274.8         0.27    649.95696    0.649957
# 7                 291.9         0.31    792.68364    0.792684
# 8                 312.8         0.28    767.23584    0.767236
# 9                 369.2         0.27    873.23184    0.873232
# 10                461.4         0.24    970.04736    0.970047
# 11                588.9         0.28   1444.45392    1.444454
# 12                657.5         0.24   1382.32800    1.382328
# 13               1032.4         0.27   2441.83248    2.441832
# 14               1454.2         0.26   3312.08592    3.312086
# 15               1872.3         0.27   4428.36396    4.428364
# 16               2444.3         0.27   5781.25836    5.781258
# 17               3064.2         0.27   7247.44584    7.247446
# 18               3458.5         0.27   8180.04420    8.180044
# 19               4056.2         0.22   7817.10864    7.817109
# 20               4560.3         0.28  11185.50384   11.185504
# 21               5888.5         0.26  13411.64760   13.411648
# 22               7417.1         0.28  18192.66288   18.192663
# 23               8257.0         0.26  18806.14320   18.806143
# 24               8810.1         0.29  22381.17804   22.381178
# 25              10131.2         0.24  21299.83488   21.299835
# 26              12213.9         0.28  29958.25392   29.958254
# 27              13090.9         0.27  30962.59668   30.962597
# 28              13450.4         0.27  31812.88608   31.812886
# 29              13532.6         0.28  33192.76128   33.192761
# 30              13717.7         0.23  27638.42196   27.638422
# 31              13813.7         0.23  27831.84276   27.831843
# 32              13903.7         0.23  28013.17476   28.013175

# %%
# Create a line plot for the number of wind turbines over time
fig1 = px.line(total_turbs, x='start_year', y='cumul_total', title='Number of Onshore Wind Turbines in the UK')

# Create a line plot for the total energy produced over time
fig2 = px.line(years_mw, x='start_year', y='GWh_annual', title='Total Energy Produced by Onshore Wind Turbines (GWh)')

# %%
#Need to convert my coordinates from British National Grid to Lat/Long to work with Folium map

import pyproj
import geopandas as gpd

# Define the BNG coordinate system (EPSG:27700)
bng = pyproj.CRS("EPSG:27700")

# Define the WGS84 coordinate system (EPSG:4326)
wgs84 = pyproj.CRS("EPSG:4326")

# Create a PyProj Transformer for the coordinate conversion
transformer = pyproj.Transformer.from_crs(bng, wgs84, always_xy=True)

# Convert BNG coordinates to latitude and longitude
converted_coords = transformer.transform(data['xcoord'].values, data['ycoord'].values)
data['longitude'], data['latitude'] = converted_coords[0], converted_coords[1]

# Print the converted coordinates
print(data[['xcoord', 'ycoord', 'latitude', 'longitude']])
# Out:
#        xcoord    ycoord   latitude  longitude
# 0    208620.0   85190.0  50.634907  -4.707688
# 1    405730.0  451820.0  53.962432  -1.914154
# 2    184500.0   54500.0  50.350880  -5.030587
# 3    432290.0  581345.0  55.125438  -1.495191
# 4    326111.0  485242.0  54.257491  -3.135725
# ..        ...       ...        ...        ...
# 755  261700.0  600000.0  55.274673  -4.178561
# 756  301279.0  185404.0  51.558849  -3.425452
# 757  363721.0  853713.0  57.572018  -2.608187
# 758  252589.0  928364.0  58.219301  -4.511210
# 759  144149.0  490451.0  54.245607  -5.928678
#
# [760 rows x 4 columns]

# %%
# Create a map showing the wind turbine locations
uk_map = folium.Map(location=[54.7023545, -3.2765753], zoom_start=6)

#Loop through each row in the dataframe
for i,row in data.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame('Site:' + str(row['site_name']))
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=200, max_width=300)
    
    #Add each row to the map
    marker = folium.Marker(location=[row['latitude'],row['longitude']],
                  popup = popup)
    marker.add_to(uk_map)
    
uk_map.save("map.html")
uk_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98982e61aa19519039635f5beb529d1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98982e61aa19519039635f5beb529d1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98982e61aa19519039635f5beb529d1d = L.map(
#                 &quot;map_98982e61aa19519039635f5beb529d1d&quot;,
#                 {
#                     center: [54.7023545, -3.2765753],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce5a6f7cd3a642e0ddbf6554e87085a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98982e61aa19519039635f5beb529d1d);
#
#
#             var marker_0e7532540de2586badea8e2f7b153a2b = L.marker(
#                 [50.63490706440539, -4.707688159636776],
#                 {}
#             ).addTo(map_98982e61aa19519039635f5beb529d1d);
#
#
#         var popup_3fef4247c03f5ed375830bc9a0c99819 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_4f7876ce22f69c157aa7a848ac3bd7db = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTaXRlOkRlbGFib2xlIFdpbmQgRmFybQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_3fef4247c03f5ed375830bc9a0c99819.setContent(i_frame_4f7876ce22f69c157aa7a848ac3bd7db);
#
#
#
#         marker_0e7532540de2586badea8e2f7b153a2b.bindPopup(popup_3fef4247c03f5ed375830bc9a0c99819)
#         ;
#
#
#
#
#             var marker_a9c6875515de34be2d15fabaeac206b1 = L.marker(
#                 [53.962432450225165, -1.9141544243898252],
#                 {}
#             ).addTo(map_98982e61aa19519039635f5beb529d1d);
#
#
#         var popup_b7f1961ee570b623a8bd1b3c1e7755da = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_0d0ab3bd692895c15e1d1aae0abc7583 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTaXRlOkNoZWxrZXIgUmVzZXJ2b2ly&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_b7f1961ee570b623a8bd1b3c1e7755da.setContent(i_frame_0d0ab3bd692895c15e1d1aae0abc7583);
#
#
#
#         marker_a9c6875515de34be2d15fabaeac206b1.bindPopup(popup_b7f1961ee570b623a8bd1b3c1e7755da)
#         ;
#
#
#
#
#             var marker_5067d7f1443367d441beddd815956873 = L.marker(
#                 [50.350879640406355, -5.0305873325454336],
#                 {}
#             ).addTo(map_98982e61aa19519039635f5beb529d1d);
#
#
#         var popup_c254d9473a877d7bcb203c78fc75de25 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_c21f08d1e32073fe9e04fe183d3cfc20 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTaXRlOkNhcmxhbmQgQ3Jvc3M=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_c254d9473a877d7bcb203c78fc75de25.setContent(i_frame_c21f08d1e32073fe9e04fe183d3cfc20);
#
#
#
#         marker_5067d7f1443367d441beddd815956873.bindPopup(popup_c254d9473a877d7bcb203c78fc75de25)
#         ;
#
#
#
#
#             var marker_6a3a46bb8a1cfc833f92d93895a1507b = L.marker(
#                 [55.12543827448606, -1.4951909213048766],
#                 {}
#             ).addTo(map_98982e61aa19519039635f5beb529d1d);
#
#
#         var popup_3e568e6d29664a062a2c717b7e2ced99 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_915b018a3780a8701c3f0f5fdb9bc348 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTaXRlOkJseXRoIEhhcmJvdXIgV2luZCBGYXJt&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_3e568e6d29664a062a2c717b7e2ced99.setContent(i_frame_915b018a3780a8701c3f0f5fdb9b

# %%
# Combine the figures into a dashboard layout (adjust the size and arrangement as needed)
fig1.update_layout(height=400)
fig2.update_layout(height=400)
uk_map = uk_map._repr_html_()

# %%
# Save the HTML file or launch a web server to view the dashboard
dashboard_html = '''
<!DOCTYPE html>
<html>
<head>
    <title>Onshore Wind Turbines Dashboard</title>
</head>
<body>
    <h1>Number of Onshore Wind Turbines in the UK</h1>
    {}
    <h1>Total Energy Produced by Onshore Wind Turbines</h1>
    {}
    <h1>Wind Turbine Locations</h1>
    {}
</body>
</html>
'''.format(fig1.to_html(full_html=False), fig2.to_html(full_html=False), uk_map)

with open('wind_turbines_dashboard.html', 'w') as f:
    f.write(dashboard_html)
